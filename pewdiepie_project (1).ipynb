# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Проект по анализу ютуб канала PewDiePie (Феликс Чельберг) - это исследование различных аспектов канала, таких как количество подписчиков, количество просмотров, тенденции роста и падения популярности и другие показатели. Анализ этого канала представляет интерес для анализа данных по нескольким причинам:
#
# - PewDiePie является одним из самых популярных ютуб каналов в мире, поэтому его анализ может помочь понять тенденции и поведение пользователей на платформе (намомент анализа у канала 111 млн. подписчиков)
#
# - Канал PewDiePie известен своим уникальным контентом, что позволяет изучать популярность и влияние контента на аудиторию.
#
# - Анализ данных канала PewDiePie может дать полезную информацию для людей, которые интересуются ютуб маркетингом, чтобы они могли лучше понимать, как создавать и продвигать контент на ютубе.
#
# - Канал PewDiePie является примером успеха в создании и продвижении ютуб канала, поэтому его анализ может быть полезен для людей, которые хотят начать свой собственный канал.
#
# - Анализ данных канала PewDiePie может помочь в понимании тенденций и трендов в контенте на ютубе, что может быть полезным для создания и продвижения собственного контента.

# %% [markdown]
# ## Цель

# %% [markdown]
# Изучить доступную информацию о канале PewDiePie и дать оценку о состоянии канала самого популярного когда-то блоггера.

# %% [markdown]
# ## Задачи

# %% [markdown]
# - Научиться пользоваться YouTube API для выгрузки информации о каналах.
# - Проанализировать доступную информацию и посмотреть:
#     - Влияет ли количество лайков на просмотры видео;
#     - Влияет ли продолжительность видео на количество просмотров;
#     - Влияет ли количество комментариев на количество просмотров;
#     - Есть ли зависимость между длинной названия видео и количеством просмотров?
# - Посмотреть другую интересную и забавную информацию:
#     - Динамику выпускаемых видео;
#     - Динамику просмотров, комментариев и лайков;
#     - Дни и время, в которые PewDiePie выпускает свои видео.
# - Сделать выводы

# %% [markdown]
# ## Выводы

# %% [markdown]
# Мы провели анализ канала PewDiePie:
#
# **Выгрузка и предобработка:**
# - С помощью API YouTube выгрузили данные о канале и видео и получили дата фрейм со следующей информацией:
#     - **video_id** - id видео
#     - **title**	- название видео
#     - **publishedAt** - дата и время публикации
#     - **viewCount**	- количество просомтров
#     - **likeCount**	- количество лайков
#     - **commentCount**	- количество комментариев
#     - **duration** - продолжительность
# - Предобработали данные: привели в нужный формат, регистр, обработали пропуски, создали нужные нам для анализа столбцы.
#
# **Анализ:**
#
# - Пик выпускаемых видео приходится на начало развития канала. Самое большое количество видео было выпущено в сентябре 2012 года - 77 штук.
# - Сегодня канал не может похвастаться такой продуктивностью, за последний год количество видео не превышает 10 в месяц.
# - Можно выделить 3 пика активности:
#     - сентярбрь  2011 - сентябрь 2013
#     - май 2014 - осень 2016
#     - сентябрь 2018 - сентябрь 2020
# - Активность блоггера подтверждена сезонности:продуктивность постепенно увеличивается к осени, а в начале года она заметно снижается.
# - Нельзя сказать, что в среди дней недели есть явные фавориты для публикации видео. Все дни находятся примерно на одном уровне по количеству выпущенных видео. Меньше всего в понедельник - 574, больше всего во вторник и пятницу - 690 и 683 видео.
# - Чаще всего видео выходят в 17:00 (UTC+0). Однако после переезда в Японию заметен сдвиг выпуска видео на утреннее часы.
# - Медианна продолжительности видео - 10 минут.
# - Медиана длины названия видео - 43 символа.
# - - Хотя пик публикации видео приходится на 2013-2015 года, пик просмотров. дайков и комментариев приходится на лето 2019, что к слову, легко объясняется:
#     - Во-первых, к тому моменту Феликс набрал достаточно количество подписчиков, чтобы не публиковать в таком огромное количестве видео. Каждое новое видео набирает в несколько раз больше просомтров, чем раньше.
#     - Во-вторых, летом 2019 была на канале была огромная активность по подпискам. Дело в том, что до 2019 канал блоггера был самым популярным в мире, но постепенно его начал догонять индийская канал T-Series. Это гонка была превращена в игру, былоа организвана "компания", где людей призывали подписываться на блоггера. В тот период и было опубликовано видео, которе сейчас является самым просматривоемым на канале.
# - Забавно, что огромное количество видео, лайков и комментариве собрало самое первое видео. Но и это легко объясняется. Уже набрав популярность, подписчикам, видимо, было интересно посмотреть на самое первое видео. Поэтому у этого видео больше 20 млн просмотров.
# - в 2018 году происходит сильный рост всех показателей, что связано с "компанией", которая была орагнизована в то время, чтобы помочь Феликсу сохранить статус самомго поулярного канала. В этот период было выпущено самое просмтравиемое видео на канале - более 300 млн. В этот период количество подписчиков превысило 100 млн.
# - Однако после 2018 года мы видим сильное падение просмотров. И хотя Феликс все еще один из самых популярных блоггеров в мире сейчас, его просмотры находятся на уровне 2013 года. Что, конечно же, по-прежнему неплохо с учетом того, что каждое видео набирает минимум несколько миллонов просмотров. Тем не менее, каждое видео просмотривает лишь 1-3% подписчиков.
# - Согласно шкале Чеддока, мы видим:
#     - Слабую коррелцию лайков и просмотров
#     - Умеренную корреляцию комментариев и просмотров
#     - Слабую корреляцию комментариев и лайков
#     - Отсутсвие корреляции между длиной видео и просмотрами
#     - И, что уже интереснее, слабую отрицательную корреляцию длины видео и лайков
#
#
# **Номинации:**
# - Самое просматриваемое видео c самым большим количеством лайков. bitch lasagna. https://www.youtube.com/watch?v=6Dh-RL__uN4&ab_channel=PewDiePie
# - Больше всего комментариев. Can this video get 1 million comments? https://www.youtube.com/watch?v=TvxkKs2J0Vw&ab_channel=PewDiePie
# - Самое длинное видео. I played Minecraft Hardcore for 12 Hours (bad things happened). https://www.youtube.com/watch?v=V-4sLymIv0M&ab_channel=PewDiePie

# %% [markdown]
# ## Исследование

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Подгружаем необходимые библиотеки
# </div>

# %%
import pandas as pd

from googleapiclient.discovery import build


import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import seaborn as sns
import isodate

import plotly.io as pio
pio.renderers.default = "svg"
svg_renderer = pio.renderers["svg"]
svg_renderer.scale = 1.2

# %% [markdown]
# ## YouTube API

# %% [markdown]
# <div class="alert alert-block alert-info">
#   Выгрузка данных с YouTube не является чем-то слыжным. Все необходимая документация есть на официальном сайте: https://developers.google.com/youtube/v3/docs/
# </div>

# %%
#через консоль разроботчика мы создали свой api ключ. На всякий случай в этом проекте ключ будет скрыт. 
api_key = 'AIzaSyCVbnaJzS7JZbbbd_rsOxn6wgNEWWu8BFw'

# %%
# id канала
channel_ids = ['UC-lHJZR3Gqxm24_Vd_AJ5Yw']

# %%
api_service_name = "youtube"
api_version = "v3"
    
youtube = build(
        api_service_name, api_version, developerKey=api_key)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Для выгрузки необходимой нам информации нужно написать 3 функции:
#
# - Для выгрузки общей статистике о канале
# - Для выгрузки id всех видео
# - Для выгрузки статистике о каждом видео
# </div>

# %%
def get_channel_stats(youtube, channel_ids):
        
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return pd.DataFrame(all_data)

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids
    
    
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['title', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'commentCount'],
                             'contentDetails': ['duration']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)
channel_stats
# Out:
#   channelName subscribers        views totalVideos                playlistId
# 0   PewDiePie   111000000  28947134568        4704  UU-lHJZR3Gqxm24_Vd_AJ5Yw

# %%
playlist_id = "UU-lHJZR3Gqxm24_Vd_AJ5Yw"

# %%
#Получаем id всех видео
video_ids = get_video_ids(youtube, playlist_id)

# %%
#Выгружаем информацию о каждом видео
video_df = get_video_details(youtube, video_ids)

video_df
# Out:
#          video_id                                              title  \
# 0     FJdb364vycg                              I'm not allowed in...
# 1     BEXqDQ6X5hM                            1 000 000 $ Motor Home.
# 2     8w2dp39NSsM    Escaping to Japan's Secret Paradise   *Okinawa*
# 3     UoNAmRwf5qk                                Kids are very dumb.
# 4     DEgt25yYidY          Gordon Ramsey VS Woman in COMPLETE denial
# ...           ...                                                ...
# 4532  hC7c1fhW1YM  Dual Minecraft Lets Play! Episode [003] - Expl...
# 4533  XONXcdJ0278  Dual Minecraft Lets Play! Episode [002] - New ...
# 4534  lUtoLyyeOwQ     Call of Duty: Black Ops: Wager Match: Gun Game
# 4535  0U6ZgImZ5vo  Blacklight Tango Down: Team Deathmatch 38-4 (P...
# 4536  9jeJbdVl2jI                          Minecraft Multiplayer Fun
#
#                publishedAt viewCount likeCount commentCount  duration
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# В конечным итоге мы получили дата фрейм со следующими данными:
#
# - **video_id** - id видео
# - **title**	- название видео
# - **publishedAt** - дата и время публикации
# - **viewCount**	- количество просомтров
# - **likeCount**	- количество лайков
# - **commentCount**	- количество комментариев
# - **duration** - продолжительность
# </div>

# %% [markdown]
# ## Предобработка данных

# %%
video_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4537 entries, 0 to 4536
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   video_id      4537 non-null   object
#  1   title         4537 non-null   object
#  2   publishedAt   4537 non-null   object
#  3   viewCount     4527 non-null   object
#  4   likeCount     4528 non-null   object
#  5   commentCount  4445 non-null   object
#  6   duration      4537 non-null   object
# dtypes: object(7)
# memory usage: 248.2+ KB

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Многие колонки выгружены с неправильными форматоми. Приведем все в нужный формат.
# </div>

# %%
#для начала для удобства приведем все в змеинный регистр
video_df = video_df.rename(columns={'publishedAt':'published_at', 
                                    'viewCount':'view_count', 'likeCount':'like_count', 
                                    'commentCount':'comment_count'})

# %%
numeric_cols = ['view_count', 'like_count', 'comment_count']

# %%
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1, downcast='integer')
video_df[numeric_cols] = video_df[numeric_cols].fillna(0)

# %%
video_df[numeric_cols] = video_df[numeric_cols].astype('int')

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Привели нужные столбцы в integer. Так же для удоства пропуски в этих столбцах хаполнили нулями.
# </div>

# %%
#созадим столбец с продолжиельностью видео в минутах
video_df['duration_in_mins'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['duration_in_mins'] = video_df['duration_in_mins'].astype('timedelta64[m]')
video_df.drop('duration', axis=1, inplace=True)

# %%
#приводим в нужный формат столбец с датой и временем публикации
video_df['published_at'] = pd.to_datetime(video_df['published_at'])

# %%
#для будущего анализа создаем столбец с номером дня недели, в который было загружено видео
video_df['week_day'] = video_df['published_at'].apply(lambda x: x.strftime("%w"))

# %%
#для будущего анализа создаем стобцы с часов, месяцем и годом, в которые были загружены видео. 
#Также создаем столбец с датой публикации, округленной до месяца

video_df['hour'] = video_df['published_at'].dt.hour
video_df['year'] = video_df['published_at'].dt.year
video_df['month'] = video_df['published_at'].dt.month
video_df['to_period'] = video_df['published_at'].dt.strftime("%Y-%m")

# %%
video_df['length_of_title'] = video_df['title'].apply(lambda x: len(x))
video_df
# Out:
#          video_id                                              title  \
# 0     FJdb364vycg                              I'm not allowed in...
# 1     BEXqDQ6X5hM                            1 000 000 $ Motor Home.
# 2     8w2dp39NSsM    Escaping to Japan's Secret Paradise   *Okinawa*
# 3     UoNAmRwf5qk                                Kids are very dumb.
# 4     DEgt25yYidY          Gordon Ramsey VS Woman in COMPLETE denial
# ...           ...                                                ...
# 4532  hC7c1fhW1YM  Dual Minecraft Lets Play! Episode [003] - Expl...
# 4533  XONXcdJ0278  Dual Minecraft Lets Play! Episode [002] - New ...
# 4534  lUtoLyyeOwQ     Call of Duty: Black Ops: Wager Match: Gun Game
# 4535  0U6ZgImZ5vo  Blacklight Tango Down: Team Deathmatch 38-4 (P...
# 4536  9jeJbdVl2jI                          Minecraft Multiplayer Fun
#
#                   published_at  view_count  like_count  comment_count  \
# ...

# %%
#Приведем фрейм в нужный нам порядок и укоротим название
df = video_df[['video_id',
 'title',
 'published_at',
 'to_period',
 'year',
 'month',
 'week_day',
 'hour',
 'view_count',
 'like_count',
 'comment_count',
 'duration_in_mins',
 'length_of_title'
 ]]

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Итак, мы сделали предобработку выгруженных данных:
#
# - привели все столбцы в нужный формат и регистр;
# - заполнили пропуски;
# - проверили на дубликаты;
# - создали столбцы с годом, месяцем, часом и днем недели публикации, которые понадобятся для будущего аналиа.
# </div>

# %% [markdown]
# ## Анализ

# %%
df
# Out:
#          video_id                                              title  \
# 0     FJdb364vycg                              I'm not allowed in...
# 1     BEXqDQ6X5hM                            1 000 000 $ Motor Home.
# 2     8w2dp39NSsM    Escaping to Japan's Secret Paradise   *Okinawa*
# 3     UoNAmRwf5qk                                Kids are very dumb.
# 4     DEgt25yYidY          Gordon Ramsey VS Woman in COMPLETE denial
# ...           ...                                                ...
# 4532  hC7c1fhW1YM  Dual Minecraft Lets Play! Episode [003] - Expl...
# 4533  XONXcdJ0278  Dual Minecraft Lets Play! Episode [002] - New ...
# 4534  lUtoLyyeOwQ     Call of Duty: Black Ops: Wager Match: Gun Game
# 4535  0U6ZgImZ5vo  Blacklight Tango Down: Team Deathmatch 38-4 (P...
# 4536  9jeJbdVl2jI                          Minecraft Multiplayer Fun
#
#                   published_at to_period  year  month week_day  hour  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Посмотрим на динамику выпускаемых видео
# </div>

# %%
df.groupby('year')['video_id'].count().reset_index()
# Out:
#     year  video_id
# 0   2010        13
# 1   2011       242
# 2   2012       642
# 3   2013       542
# 4   2014       547
# 5   2015       576
# 6   2016       434
# 7   2017       336
# 8   2018       273
# 9   2019       354
# 10  2020       265
# 11  2021       225
# 12  2022        76
# 13  2023        12

# %%
publish = df.groupby(['to_period', 'year'])['video_id'].count().reset_index()
fig = px.bar(publish, x='to_period', y='video_id')
fig.update_layout(title='Публикации видео по месяцам',
                   xaxis_title='Год и месяц',
                   yaxis_title='Количество выпущенных видео')

fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Отчетливо заметно, что самое большое количество видео было выпущено в начале развития канала. Пик количества видео приходится на сентябрь 2012, в котором было выпущено аж 77 видео. Удивительная продуктивность.
#
# Так же видим, что постепенно, количество видео падает. И за последний год количество видео не превышает 10 в месяц.
#
# Хорошо заметы и пики активности, которые можем поделить на 3 этапа:
#
# - сентярбрь  2011 - сентябрь 2013
# - май 2014 - осень 2016
# - сентябрь 2018 - сентябрь 2020
# </div>

# %%
#попробуем посмотреть активность по месяцам
month = df.groupby('month')['video_id'].count().reset_index()
fig = px.bar(month, x='month', y='video_id')
fig.update_layout(title='Публикации видео по месяцам',
                   xaxis_title='Номер месяца',
                   yaxis_title='Количество выпущенных видео')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#    В целом можно заметить, что продуктивность блоггера постепенно увеличивается к осени, а в начале года она заметно снижается.
# </div>

# %%
#Публикация видео по дням недели
day_week = df.groupby('week_day')['video_id'].count().reset_index()
fig = px.bar(day_week, x='week_day', y='video_id')
fig.update_layout(title='Публикации видео по дням недели',
                   xaxis_title='День недели, где 0 - воскресение',
                   yaxis_title='Количество выпущенных видео')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Нельзя сказать, что в среди дней недели есть явные фавориты для публикации видео. Все дни находятся примерно на одном уровне по количеству выпущенных видео. Меньше всего в понедельник - 574, больше всего во вторник и пятницу - 690 и 683 видео.
# </div>

# %%
#публикация видео по часам
hour = df.groupby('hour')['video_id'].count().reset_index()
fig = px.bar(hour, x='hour', y='video_id')
fig.update_layout(title='Расписание публикаций видео',
                   xaxis_title='Время',
                   yaxis_title='Количество выпущенных видео')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     В данном случае мы наблюдаем явный пик времени публикации на 17 часов. Стоит отметить, что время указано UTC+0. Было решено оставить этот часовой пояс, так блоггер большую часть своей жизни прожил в Англии. Будем предполагать, что он ориаентировался на этот часовой пояс при публикации своих видео.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Интересно, кстати, посмотреть, изменилось ли время публикаций видео после того, как Феликс переехал в Японию. С марта 2022 года блоггер проживает в Японии.
# </div>

# %%
#публикация видео по часам после переезда
hour = df.query('to_period > "2022-03"').groupby('hour')['video_id'].count().reset_index()
fig = px.bar(hour, x='hour', y='video_id')
fig.update_layout(title='Расписание публикаций видео после переезда в Японию',
                   xaxis_title='Время',
                   yaxis_title='Количество выпущенных видео')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     С момента переезда, к сожалению, было выпущено не слишком много видео, поэтому видим не совсем нормальное распределение на графике. Тем не менее, можно явно заметить два факта:
#
# - Пик публикацй все еще приходится на 16-17 часов.
# - Видно небольшое смещение времени публикаций видео на утренние часы, что выглядит логичным. Когда в Лондоне утро, в Токио уже вечер. Видимо, переезд так повлиял на врем публикации видео.
# </div>

# %%
df.duration_in_mins.describe()
# Out:
# count    4537.000000
# mean       15.917126
# std        23.939476
# min         0.000000
# 25%         8.000000
# 50%        11.000000
# 75%        16.000000
# max       722.000000
# Name: duration_in_mins, dtype: float64

# %%
#глянем на распределение продолжительности видео
duration = df.query('duration_in_mins < 50')
fig = px.histogram(duration, x='duration_in_mins')
fig.update_layout(title='Продолжительность видео',
                   xaxis_title='Минуты',
                   yaxis_title='Количество видео')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Мы ограничили видео до 50 минут. В фрейме есть видео, которые длятся 12 часов.
# Большинство видео длятся 10 минут. Забавно, чтовидео с продолжительностью 9 минут в три раза меньше, чем видео с продолжительностью 10 минут. По всей видимости, Феликс чаще пытался растянуть свои видео именно до 10 минут.
# </div>

# %%
#Изучим распределение длинны названия видео

fig = px.histogram(df, x='length_of_title', nbins=99)
fig.update_layout(title='Распределение длины названий видео',
                   xaxis_title='Количество символов',
                   yaxis_title='Количество видео')
fig.show()

# %%
df.length_of_title.describe()
# Out:
# count    4537.000000
# mean       44.375579
# std        18.843093
# min         2.000000
# 25%        31.000000
# 50%        43.000000
# 75%        57.000000
# max       100.000000
# Name: length_of_title, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Медианна длины названия - 43 символа. Максимум - 100, минимум 2
# </div>

# %%
# изучим распределение комментариев
comments = df.query('comment_count < 200000')
fig = px.histogram(comments, x='comment_count')
fig.update_layout(title='Распределение комментариев',
                   xaxis_title='Количество комментариев',
                   yaxis_title='Количество видео')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Очень странный выброс в количестве комментариев до 2 тысяч. Глянем ближе
# </div>

# %%
comments = df.query('comment_count < 2000')
fig = px.histogram(comments, x='comment_count')
fig.update_layout(title='Распределение комментариев',
                   xaxis_title='Количество комментариев',
                   yaxis_title='Количество видео')
fig.show()

# %%
comments = df.query('comment_count < 100')
fig = px.histogram(comments, x='comment_count')
fig.update_layout(title='Распределение комментариев',
                   xaxis_title='Количество комментариев',
                   yaxis_title='Количество видео')
fig.show()

# %%
fig = px.bar(df.query('comment_count < 100'), x='to_period', y='video_id')
fig.update_layout(title='Видео с комментариями до 100 штук',
                   xaxis_title='Дата',
                   yaxis_title='Количество')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Очень интересный глюк. Мы видим большое количество видео с комментариеми до 100 штук, при этом у этих видео открыта возможность комментировать и просмотров несколько миллионов на каждом. Предположу, что это глюк счетчика ютуба.
#
#
# Однако если убрать эти видео из фрейма, то получается интересная ситуация. большая часть этих видео приходится на период август 2014 - август 2015. Если их убрать из фрейма, то на дальнейших графиках в этом периоде получается дыра.
#
#
# Оставляем эти видео во фрейме.
# </div>

# %%
comments = df.query('100 < comment_count < 200000')
fig = px.histogram(comments, x='comment_count')
fig.update_layout(title='Распределение комментариев после работы с выбросами',
                   xaxis_title='Комментарии',
                   yaxis_title='Количество видео' )
fig.show()

# %%
df.comment_count.describe()
# Out:
# count    4.537000e+03
# mean     1.941281e+04
# std      4.393430e+04
# min      0.000000e+00
# 25%      4.417000e+03
# 50%      1.238700e+04
# 75%      2.358200e+04
# max      1.698950e+06
# Name: comment_count, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Медиана комментариев составляет 15 тысяч.
# </div>

# %%
#посмотрим на медианное распределение просмотров 
period = df.groupby('to_period')[['view_count', 'like_count', 'comment_count']].median().reset_index()

# %%
fig = px.line(period, x='to_period', y='view_count')
fig.update_layout(title='Медианное распределение просмотров',
                   xaxis_title='Дата',
                   yaxis_title='Просмотры')
fig.show()

# %%
#медианное распределение лайков и комментариев 
fig = px.line(period, x='to_period', y=['like_count', 'comment_count'])
fig.update_layout(title='Медианное распределение лайков и комментариев',
                   xaxis_title='Дата',
                   yaxis_title='Количество')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# Можно заметить несколько интересных фактов:
#
# - Хотя пик публикации видео приходится на 2013-2015 года, пик просмотров. дайков и комментариев приходится на лето 2019, что к слову, легко объясняется:
#
#     - Во-первых, к тому моменту Феликс набрал достаточно количество подписчиков, чтобы не публиковать в таком огромное количестве видео. Каждое новое видео набирает в несколько раз больше просомтров, чем раньше.
#     - Во-вторых, летом 2019 была на канале была огромная активность по подпискам. Дело в том, что до 2019 канал блоггера был самым популярным в мире, но постепенно его начал догонять индийская канал T-Series. Это гонка была превращена в игру, былоа организвана "компания", где людей призывали подписываться на блоггера. В тот период и было опубликовано видео, которе сейчас является самым просматривоемым на канале.
#
# - Забавно, что огромное количество видео, лайков и комментариве собрало самое первое видео. Но и это легко объясняется. Уже набрав популярность, подписчикам, видимо, было интересно посомтреть на самое первое видео. Поэтому у этого видео больше 20 млн просмотров
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Тем не менее, анали просмотров по их общему анализу несовсем корректнен. Более показательным будем анализ просомтров по месяцам согласно среднему коичеству. Построим график:
# </div>

# %%
views_per_video = df.groupby('to_period').agg({'view_count':'sum', 'video_id':'count'})

# %%
views_per_video['views_per_video'] = views_per_video['view_count']/views_per_video['video_id']

# %%
fig = px.bar(views_per_video, y='views_per_video')
fig.update_layout(title='Распределение среднего количества просмотров',
                   xaxis_title='Дата',
                   yaxis_title='Просмотры')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# А вот это уже интереснее. Получается, что фактически второй пик просмотров не слишком сильно превосходит первй пик.
# После пика просмотров в 2014 году мы видим паденее и постепенный рост к 2018 году. Однако мы видим множество выбросов, которые связаны с "борьбой" с T-Series. Несмотря на то, что в 2018 году количество подписчиков было в разы больше, чем в 2014, пик просмотров в 2018 не сильно выше.
#
# Более того, после 2018 года мы видим сильное падение просмотров. И хотя Феликс все еще один из самых популярных блоггеров в мире сейчас, его просмотры находятся на уровне 2013 года. Что, конечно же, по-прежнему неплохо с учетом того, что каждое видео набирает минимум несколько миллонов просмотров.
# </div>

# %%
#Изучим корреляцию просмотров, лайков и комментариев
data_to_pair = df.query('view_count < 100000000 & view_count != 0')
data_to_pair = df.query('like_count < 8000000 & like_count != 0')
data_to_pair = df.query('100 < comment_count < 500000')


sns.pairplot(data = data_to_pair[['view_count', 'like_count', 'comment_count', 'length_of_title']])

# %%
data_to_pair.comment_count.describe()
# Out:
# count      3897.000000
# mean      21135.595330
# std       24192.131527
# min         115.000000
# 25%        7563.000000
# 50%       15096.000000
# 75%       25757.000000
# max      332039.000000
# Name: comment_count, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data_to_pair[['view_count', 'like_count', 'comment_count', 'length_of_title']].corr(), 
            annot = True, fmt='.2g', center= 0, cmap= 'coolwarm')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# Согласно шкале Чеддока, мы видим:
#
# - Слабую коррелцию лайков и просомтров
# - Умеренную корреляцию комментариев и просмотров
# - Слабую уорреляцию комментариев и лайков
# - и, что уже интереснее, слабую отрицательную корреляцию длины видео и лайков
# </div>

# %%
#отдельно посмотрим на корреляцию продолжительности видео и просмотров
fig = px.scatter(df.query('duration_in_mins < 50'), x='duration_in_mins', y='view_count')
fig.update_layout(title='Парный график продолжительности видео и количества просмотров',
                   xaxis_title='Длина видео в минутах',
                   yaxis_title='Просмотры')
fig.show()

# %%
print(df[['duration_in_mins', 'view_count']].corr())
# Out:
#                   duration_in_mins  view_count
# duration_in_mins          1.000000   -0.016101
# view_count               -0.016101    1.000000

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Снова не забыли убрать слишком длинные видео.
# Забавно, но получается, что PewDiePie нет заметно корреляции между продолжительностью видео и количество просмотров. Она совсем незначительная.
# </div>

# %%
#Напоследок выясним топ 10 видео по просмотрам.
fig = px.bar(df.sort_values('view_count', ascending=False)[0:10], 
       x = 'title', 
       y = 'view_count',
       color_discrete_sequence=px.colors.qualitative.Safe)

fig.update_layout(title='ТОП 10 видео',
                   xaxis_title='Название',
                   yaxis_title='Просмотры')
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Ну и найдем видео по "номинациям":
# </div>

# %%
#Видео с самым большим количеством лайков
df.loc[df['like_count'].idxmax()]
# Out:
# video_id                          6Dh-RL__uN4
# title                           bitch lasagna
# published_at        2018-10-05 17:16:40+00:00
# to_period                             2018-10
# year                                     2018
# month                                      10
# week_day                                    5
# hour                                       17
# view_count                          312969596
# like_count                           12809789
# comment_count                         1228740
# duration_in_mins                          2.0
# length_of_title                            13
# Name: 1005, dtype: object

# %%
#Видео с самым большим количеством комментариев
df.loc[df['comment_count'].idxmax()]
# Out:
# video_id                                       TvxkKs2J0Vw
# title               Can this video get 1 million comments?
# published_at                     2017-01-28 18:36:35+00:00
# to_period                                          2017-01
# year                                                  2017
# month                                                    1
# week_day                                                 6
# hour                                                    18
# view_count                                        18723801
# like_count                                         1364824
# comment_count                                      1698950
# duration_in_mins                                       4.0
# length_of_title                                         38
# Name: 1511, dtype: object

# %%
#видео с самым большим количеством просмотров
df.loc[df['view_count'].idxmax()]
# Out:
# video_id                          6Dh-RL__uN4
# title                           bitch lasagna
# published_at        2018-10-05 17:16:40+00:00
# to_period                             2018-10
# year                                     2018
# month                                      10
# week_day                                    5
# hour                                       17
# view_count                          312969596
# like_count                           12809789
# comment_count                         1228740
# duration_in_mins                          2.0
# length_of_title                            13
# Name: 1005, dtype: object

# %%
#Самое длиное видео
df.loc[df['duration_in_mins'].idxmax()]
# Out:
# video_id                                                  V-4sLymIv0M
# title               I played Minecraft Hardcore for 12 Hours (bad ...
# published_at                                2019-09-18 16:12:48+00:00
# to_period                                                     2019-09
# year                                                             2019
# month                                                               9
# week_day                                                            3
# hour                                                               16
# view_count                                                   18739373
# like_count                                                     810905
# comment_count                                                   66675
# duration_in_mins                                                722.0
# length_of_title                                                    62
# Name: 681, dtype: object

# %%
#самое длинное название. Таких видео несколько. По всей видимости, это ограничение ютуб в 100 символов. 
df[df['length_of_title'] == 100]
# Out:
#          video_id                                              title  \
# 91    zLpVBsvcrAg  Tik Tok Survival Training........................
# 101   15Mcob5_tyU  They figured out atoms existed thousands of ye...
# 1965  xDuNSbF5xxo  CAN'T...... STOP................ DYING...........
# 2710  XU5JJraK7jQ  Alien: Isolation - Gameplay - Part 1 - (Playth...
# 4387  l42fUzw_a7E  [Funny/Horror] Amnesia: BE PATIENT, ARE YOU F-...
#
#                   published_at to_period  year  month week_day  hour  \
# 91   2021-12-27 18:22:50+00:00   2021-12  2021     12        1    18
# 101  2021-12-10 17:27:48+00:00   2021-12  2021     12        5    17
# 1965 2016-01-10 16:00:03+00:00   2016-01  2016      1        0    16
# 2710 2014-09-27 20:43:19+00:00   2014-09  2014      9        6    20
# 4387 2011-10-16 17:27:57+00:00   2011-10  2011     10        0    17
#
#       view_count  like_count  comment_count  duration_in_mins  length_of_title
# ...

# %%
#самое короткое название. Такой видео оказалось только 1. 
df[df['length_of_title'] == 2]
# Out:
#          video_id title              published_at to_period  year  month  \
# 2053  bTB25cgO8YM    GG 2015-10-24 17:30:00+00:00   2015-10  2015     10
#
#      week_day  hour  view_count  like_count  comment_count  duration_in_mins  \
# 2053        6    17     6264212      244393          18856              12.0
#
#       length_of_title
# 2053                2

# %%
#первое видео
df.loc[df['published_at'].idxmin()]
# Out:
# video_id                          9jeJbdVl2jI
# title               Minecraft Multiplayer Fun
# published_at        2010-10-03 00:45:31+00:00
# to_period                             2010-10
# year                                     2010
# month                                      10
# week_day                                    0
# hour                                        0
# view_count                           21394107
# like_count                             910227
# comment_count                          161096
# duration_in_mins                          2.0
# length_of_title                            25
# Name: 4536, dtype: object

# %% [markdown]
# ## Выводы

# %% [markdown]
# Мы провели анализ канала PewDiePie:
#
# **Выгрузка и предобработка:**
# - С помощью API YouTube выгрузили данные о канале и видео и получили дата фрейм со следующей информацией:
#     - **video_id** - id видео
#     - **title**	- название видео
#     - **publishedAt** - дата и время публикации
#     - **viewCount**	- количество просомтров
#     - **likeCount**	- количество лайков
#     - **commentCount**	- количество комментариев
#     - **duration** - продолжительность
# - Предобработали данные: привели в нужный формат, регистр, обработали пропуски, создали нужные нам для анализа столбцы.
#
# **Анализ:**
#
# - Пик выпускаемых видео приходится на начало развития канала. Самое большое количество видео было выпущено в сентябре 2012 года - 77 штук.
# - Сегодня канал не может похвастаться такой продуктивностью, за последний год количество видео не превышает 10 в месяц.
# - Можно выделить 3 пика активности:
#     - сентярбрь  2011 - сентябрь 2013
#     - май 2014 - осень 2016
#     - сентябрь 2018 - сентябрь 2020
# - Активность блоггера подтверждена сезонности:продуктивность постепенно увеличивается к осени, а в начале года она заметно снижается.
# - Нельзя сказать, что в среди дней недели есть явные фавориты для публикации видео. Все дни находятся примерно на одном уровне по количеству выпущенных видео. Меньше всего в понедельник - 574, больше всего во вторник и пятницу - 690 и 683 видео.
# - Чаще всего видео выходят в 17:00 (UTC+0). Однако после переезда в Японию заметен сдвиг выпуска видео на утреннее часы.
# - Медианна продолжительности видео - 10 минут.
# - Медиана длины названия видео - 43 символа.
# - - Хотя пик публикации видео приходится на 2013-2015 года, пик просмотров. дайков и комментариев приходится на лето 2019, что к слову, легко объясняется:
#     - Во-первых, к тому моменту Феликс набрал достаточно количество подписчиков, чтобы не публиковать в таком огромное количестве видео. Каждое новое видео набирает в несколько раз больше просомтров, чем раньше.
#     - Во-вторых, летом 2019 была на канале была огромная активность по подпискам. Дело в том, что до 2019 канал блоггера был самым популярным в мире, но постепенно его начал догонять индийская канал T-Series. Это гонка была превращена в игру, былоа организвана "компания", где людей призывали подписываться на блоггера. В тот период и было опубликовано видео, которе сейчас является самым просматривоемым на канале.
# - Забавно, что огромное количество видео, лайков и комментариве собрало самое первое видео. Но и это легко объясняется. Уже набрав популярность, подписчикам, видимо, было интересно посмотреть на самое первое видео. Поэтому у этого видео больше 20 млн просмотров.
# - в 2018 году происходит сильный рост всех показателей, что связано с "компанией", которая была орагнизована в то время, чтобы помочь Феликсу сохранить статус самомго поулярного канала. В этот период было выпущено самое просмтравиемое видео на канале - более 300 млн. В этот период количество подписчиков превысило 100 млн.
# - Однако после 2018 года мы видим сильное падение просмотров. И хотя Феликс все еще один из самых популярных блоггеров в мире сейчас, его просмотры находятся на уровне 2013 года. Что, конечно же, по-прежнему неплохо с учетом того, что каждое видео набирает минимум несколько миллонов просмотров. Тем не менее, каждое видео просмотривает лишь 1-3% подписчиков.
# - Согласно шкале Чеддока, мы видим:
#     - Слабую коррелцию лайков и просмотров
#     - Умеренную корреляцию комментариев и просмотров
#     - Слабую корреляцию комментариев и лайков
#     - Отсутсвие корреляции между длиной видео и просмотрами
#     - И, что уже интереснее, слабую отрицательную корреляцию длины видео и лайков
#
#
# **Номинации:**
# - Самое просматриваемое видео c самым большим количеством лайков. bitch lasagna. https://www.youtube.com/watch?v=6Dh-RL__uN4&ab_channel=PewDiePie
# - Больше всего комментариев. Can this video get 1 million comments? https://www.youtube.com/watch?v=TvxkKs2J0Vw&ab_channel=PewDiePie
# - Самое длинное видео. I played Minecraft Hardcore for 12 Hours (bad things happened). https://www.youtube.com/watch?v=V-4sLymIv0M&ab_channel=PewDiePie
